# %%
# Import Dependencies
# !pip install requests
import requests

# %%
# IGDB API endpoint URL
url = "https://api.igdb.com/v4/games"

# %%
# API headers with Client-ID and Access Token
headers = {
    "Client-ID": "oiobf6gw0o9cn4cnialwdo6ltddvmq",
    "Authorization": "Bearer rbk6v3ueq49kfy45vqtrr6w4iey5w4",
    "Content-Type": "application/json"
}

# %%
# Define platform IDs for different platforms (replace with actual IDs)
pc_platform_id = 6
ps5_platform_id = 167
xbox_platform_id = 169
switch_platform_id = 130

# Define the API endpoint and query parameters
url = "https://api.igdb.com/v4/games"
params = {
    "fields": "name,platforms",
    "limit": 10,  # Limit the results to 10 games
}

# Make a GET request to fetch game data
response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    game_data = response.json()

    # Separate data for different platforms
    pc_games = [game for game in game_data if pc_platform_id in game.get("platforms", [])]
    ps5_games = [game for game in game_data if ps5_platform_id in game.get("platforms", [])]
    xbox_games = [game for game in game_data if xbox_platform_id in game.get("platforms", [])]
    switch_games = [game for game in game_data if switch_platform_id in game.get("platforms", [])]

    # Display or use the separated data
    print("PC Games:", pc_games)
    print("PlayStation 5 Games:", ps5_games)
    print("Xbox Series X/S Games:", xbox_games)
    print("Nintendo Switch Games:", switch_games)
else:
    print(f"Error: {response.status_code}")
# Out:
# PC Games: [{'id': 121973, 'name': 'Agross', 'platforms': [6]}, {'id': 246925, 'name': 'Stickman and the Sword of Legends', 'platforms': [6]}]
# PlayStation 5 Games: []
# Xbox Series X/S Games: []
# Nintendo Switch Games: []

# %%
# Specify the fields you want to retrieve and the sorting order
params = {
    "fields": "name,platforms",
    "limit": 5,  # Limit the results to the top 5 games
    "order": "popularity:desc",  # Sort by popularity in descending order
}


# Make a GET request to fetch game data
response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    game_data = response.json()

    # Separate the data based on platforms
    pc_games = []
    ps5_games = []
    xbox_games = []
    switch_games = []
    mobile_games = []

    for game in game_data:
        platforms = game.get("platforms", [])
        game_name = game.get("name", "N/A")

        if 6 in platforms:  # PC platform ID
            pc_games.append(game_name)
        if 167 in platforms:  # PlayStation 5 platform ID
            ps5_games.append(game_name)
        if 169 in platforms or 170 in platforms:  # Xbox Series X/S platform IDs
            xbox_games.append(game_name)
        if 130 in platforms:  # Nintendo Switch platform ID
            switch_games.append(game_name)
        if 34 in platforms:  # Mobile platform ID
            mobile_games.append(game_name)

    # Print the games for each platform
    print("PC Games:")
    print(pc_games)
    print("\nPlayStation 5 Games:")
    print(ps5_games)
    print("\nXbox Series X/S Games:")
    print(xbox_games)
    print("\nNintendo Switch Games:")
    print(switch_games)
    print("\nMobile Games:")
    print(mobile_games)
else:
    print(f"Error: {response.status_code}")
# Out:
# PC Games:
# ['Agross']
#
# PlayStation 5 Games:
# []
#
# Xbox Series X/S Games:
# []
#
# Nintendo Switch Games:
# []
#
# Mobile Games:
# []

# %%
# Specify the filters and fields you want to retrieve
# In this example, we're querying platforms by name and retrieving some basic fields
params = {
    "fields": "name,alternative_name,generation",
    "limit": 40,  # You can adjust the limit to control the number of results returned
}

# Make a GET request to fetch platform data
response = requests.get(
   "https://api.igdb.com/v4/platforms",
   headers=headers,
   params=params
)

if response.status_code == 200:
   platform_data = response.json()
   # Process and print the platform data
   for platform in platform_data:
       platform_name = platform.get('name', 'N/A')
       alternative_name = platform.get('alternative_name', 'N/A')
       generation = platform.get('generation', 'N/A')
       

       print(f"Platform Name: {platform_name}")
       print(f"Alternative Name: {alternative_name}")
       print(f"Generation: {generation}")
       print("\n")
else:
   print(f"Error: {response.status_code}")
# Out:
# Platform Name: Commodore CDTV
# Alternative Name: Commodore Dynamic Total Vision
# Generation: N/A
#
#
# Platform Name: Sega Pico
# Alternative Name: Kids Computer Pico
# Generation: 4
#
#
# Platform Name: PlayStation 2
# Alternative Name: PS2
# Generation: 6
#
#
# Platform Name: iOS
# Alternative Name: N/A
# Generation: N/A
#
#
# Platform Name: Commodore Plus/4
# Alternative Name: N/A
# Generation: N/A
#
#
# Platform Name: AY-3-8710
# Alternative Name: N/A
# Generation: N/A
#
#
# Platform Name: Odyssey
# Alternative Name: Magnavox Odyssey; Odysee; Odisea; Odissea
# Generation: 1
#
#
# Platform Name: Commodore PET
# Alternative Name: N/A
# Generation: N/A
#
#
# Platform Name: Sol-20
# Alternative Name: N/A
# Generation: N/A
#
#
# Platform Name: PC (Microsoft Windows)
# Alternative Name: mswin
# Generation: N/A
#
#
# Platform Name: Tapwave Zodiac
# Alternative Name: N/A
# Generation: N/A
#
#
# Platform Name: ColecoVision
# Alternative Name: N/A
# Generation: 2
#
#
# ...

# %%
# Specify the fields you want to retrieve, including the popularity criteria (e.g., total_games)
params = {
    "fields": "platform_name,alternative_name,total_games",
    "limit": 10,  # Limit the results to the top 10 platforms
    "order": "total_games:desc",  # Sort by total games in descending order
}

# Make a GET request to fetch platform data
response = requests.get(
   "https://api.igdb.com/v4/platforms",
   headers=headers,
   params=params
)

if response.status_code == 200:
   platform_data = response.json()
   # Process and print the top 10 most popular platforms
   for index, platform in enumerate(platform_data, start=1):
       platform_name = platform.get('name', 'N/A')
       alternative_name = platform.get('alternative_name', 'N/A')
       total_games = platform.get('total_games', 'N/A')

       print(f"Rank: {index}")
       print(f"Platform Name: {platform_name}")
       print(f"Alternative Name: {alternative_name}")
       print(f"Total Games: {total_games}")
       print("\n")
else:
   print(f"Error: {response.status_code}")
# Out:
# Error: 400

# %%
params = {
    "fields": "name,alternative_name,total_games",
    "limit": 10,
    "order": "total_games:desc"
}

# %%
# Get a list of consoles
response = requests.get("https://api.igdb.com/v4/platforms", headers=headers)

if response.status_code == 200:
    console_data = response.json()
else:
    print(f"Error: {response.status_code}")

# %%
for console in console_data:
    platform_id = console['id']
    
    # Get games for a specific console
    response = requests.get(
        "https://api.igdb.com/v4/games",
        headers=headers,
        params={"fields": "name,genres", "where": f"platforms={platform_id}"}
    )
    
    if response.status_code == 200:
        games_data = response.json()
        # Now, you have games for a specific console in games_data
        # You can further process this data, including sorting by genres
    else:
        print(f"Error: {response.status_code}")

# %%
# Example code to group games by genre
games_by_genre = {}

for game in games_data:
    for genre_id in game.get('genres', []):
        genre_name = genre_id  # Replace with actual logic to get genre names
        if genre_name not in games_by_genre:
            games_by_genre[genre_name] = []
        games_by_genre[genre_name].append(game['name'])

# %%
# Get a list of consoles
response = requests.get("https://api.igdb.com/v4/platforms", headers=headers)

if response.status_code == 200:
    console_data = response.json()
else:
    print(f"Error: {response.status_code}")

# Loop through the list of consoles
for console in console_data:
    platform_id = console['id']
    platform_name = console['name']  # Get the console's name

    # Print the name of the console you're querying
    print(f"Querying data for console: {platform_name}")

    # Get games for a specific console
    response = requests.get(
        "https://api.igdb.com/v4/games",
        headers=headers,
        params={"fields": "name,genres", "where": f"platforms={platform_id}"}
    )

    if response.status_code == 200:
        games_data = response.json()
        # Now, you have games for a specific console in games_data
        # You can further process this data, including sorting by genres
    else:
        print(f"Error: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 12
#      10 for console in console_data:
#      11     platform_id = console['id']
# ---> 12     platform_name = console['name']  # Get the console's name
#      14     # Print the name of the console you're querying
#      15     print(f"Querying data for console: {platform_name}")
#
# KeyError: 'name'

# %%
params = {
    "fields": "name,summary",  # Specify the fields you want to retrieve
    "limit": 5,               # Limit the number of results to 5 for testing
}

# %%
# Make the GET request
response = requests.get(url, headers=headers, params=params)

# Check the response status code
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    print(data)  # Print the JSON data to inspect the response
else:
    print(f"Error: {response.status_code}")
# Out:
# [{'id': 121973, 'name': 'Agross', 'summary': 'Agross is a survival resource management game . You play the role of a farmer.'}, {'id': 2563, 'name': 'Dragon Ball Z: Budokai', 'summary': 'Join us on a wild ride through the best action cartoon series on TV, Dragonball Z. The story begins after Goku defeats Piccolo at the World Marital Arts Tournament and he comes to visit Master Roshi, when all of a sudden, his brother Raditz appears and kidnaps his son, Gohan, after he saves him he is sent to Other World to train with King Kai for for two more powerful Saiyan arriving one year later. This wild ride story takes you from the Saiyan to the Cell Games Saga.\n\nThere are also several options in the game: there is a world tournament mode where you could buy new moves and a practice mode where you can sharpen your skills before entering story mode. You could also summon Shenron when you collect all 7 Dragonballs. So, buckle up, hold on to your seat and enjoy the ride of Dragonball Z!'}, {'id
# ...

# %%
print("Request URL:", response.url)
# Out:
# Request URL: https://api.igdb.com/v4/games?fields=name%2Csummary&limit=5

# %%
# Defined query parameters to retrieve console details
params = {
    "fields": "name,generation,company,release_date,cpu,gpu,memory,storage,media",
    "order": "generation:asc",  # Order consoles by generation (ascending)
}

# %%
# Make a GET request to the IGDB API to fetch console data
response = requests.get(url, headers=headers, params=params)
# Check if the request was successful (HTTP status code 200)
if response.status_code == 200:
    # Parse the JSON response
    console_data = response.json()  # This line extracts JSON data from the response

    # Now, you can work with the `console_data` variable, which contains the JSON response
else:
    print(f"Error: {response.status_code}")
# Out:
# Error: 400

# %%
# Check if the request was successful (HTTP status code 200)
if response.status_code == 200:
    # Parse the JSON response
    game_data = response.json()
    
    # Check if the response contains any data
    if game_data:
        # Iterate through the game data and print relevant information
        for game in game_data:
            print(f"Game Name: {game['name']}")
            print(f"Game Generation: {game['generation']}")
            print(f"Company: {game['company']}")
            print(f"Release Date: {game['release_date']}")
            print(f"CPU: {game['cpu']}")
            print(f"GPU: {game['gpu']}")
            print(f"Memory: {game['memory']}")
            print(f"Storage: {game['storage']}")
            print(f"Media Support: {game['media']}")
            print("\n")
    else:
        print("No game data found in the response.")
else:
    print(f"Error: {response.status_code}")
# Out:
# Error: 400
